# %%
pip install cufflinks
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
import cufflinks as cf

# %%
np.random.random(100)
# Out:
# array([0.14060431, 0.15765159, 0.27784951, 0.13025014, 0.09178889,
#        0.41017022, 0.04171373, 0.85999453, 0.43004921, 0.45687564,
#        0.24845147, 0.89613671, 0.66416682, 0.44217229, 0.30914329,
#        0.92579841, 0.64551291, 0.49953152, 0.56862455, 0.34818896,
#        0.11346367, 0.4638333 , 0.74627756, 0.20934364, 0.92244973,
#        0.56881483, 0.7201387 , 0.56132527, 0.90883806, 0.04358398,
#        0.90436844, 0.10611695, 0.94356868, 0.8883836 , 0.62541689,
#        0.19549344, 0.36155141, 0.93260661, 0.40514382, 0.29063238,
#        0.23040536, 0.87032007, 0.70482706, 0.67115862, 0.17937233,
#        0.75923629, 0.54176179, 0.91920667, 0.121994  , 0.93420662,
#        0.33978156, 0.16326798, 0.58111372, 0.51878327, 0.50271723,
#        0.03863952, 0.09317475, 0.20766871, 0.96221508, 0.32909607,
#        0.43510801, 0.78410614, 0.63096246, 0.81477103, 0.46072042,
#        0.77332061, 0.20601482, 0.55288853, 0.94549125, 0.283141  ,
# ...

# %%
a = pd.DataFrame(np.random.random(100))

# %%
a
# Out:
#            0
# 0   0.177444
# 1   0.505428
# 2   0.963532
# 3   0.669912
# 4   0.680320
# ..       ...
# 95  0.506818
# 96  0.699250
# 97  0.999368
# 98  0.651752
# 99  0.594549
#
# [100 rows x 1 columns]

# %%
b = pd.DataFrame(np.random.random(100))

# %%
b
# Out:
#            0
# 0   0.418990
# 1   0.432160
# 2   0.345760
# 3   0.021142
# 4   0.239045
# ..       ...
# 95  0.239375
# 96  0.787826
# 97  0.016806
# 98  0.916851
# 99  0.963628
#
# [100 rows x 1 columns]

# %%
c = pd.DataFrame(np.random.random(100))

# %%
c
# Out:
#            0
# 0   0.847415
# 1   0.385278
# 2   0.666339
# 3   0.915834
# 4   0.056557
# ..       ...
# 95  0.743501
# 96  0.065032
# 97  0.817191
# 98  0.105902
# 99  0.384469
#
# [100 rows x 1 columns]

# %%
df= pd.concat([a,b,c],axis=1)

# %%
df
# Out:
#            0         0         0
# 0   0.177444  0.418990  0.847415
# 1   0.505428  0.432160  0.385278
# 2   0.963532  0.345760  0.666339
# 3   0.669912  0.021142  0.915834
# 4   0.680320  0.239045  0.056557
# ..       ...       ...       ...
# 95  0.506818  0.239375  0.743501
# 96  0.699250  0.787826  0.065032
# 97  0.999368  0.016806  0.817191
# 98  0.651752  0.916851  0.105902
# 99  0.594549  0.963628  0.384469
#
# [100 rows x 3 columns]

# %%
df.head()
# Out:
#           0         0         0
# 0  0.177444  0.418990  0.847415
# 1  0.505428  0.432160  0.385278
# 2  0.963532  0.345760  0.666339
# 3  0.669912  0.021142  0.915834
# 4  0.680320  0.239045  0.056557

# %%
df.plot()
# Out:
# <Axes: >

# %%
df = pd.read_csv('titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.lineplot(data=df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
d = [1,2,3,4,5]

# %%
sns.lineplot(data=d)
# Out:
# <Axes: >

# %%
sns.barplot(data=df, x = 'Survived', y='Sex')
# Out:
# <Axes: xlabel='Survived', ylabel='Sex'>

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df1 = sns.load_dataset('tips')

# %%
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(data=df1, x = 'tip', y = 'total_bill')
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.relplot(data=df1,x = 'tip', y = 'total_bill', hue='smoker')

# %%
sns.relplot(data=df1,x = 'tip', y = 'total_bill', hue='time')

# %%
sns.relplot(data=df1,x = 'tip', y = 'total_bill', style='size')

# %%
sns.relplot(data=df1,x = 'tip', y = 'total_bill', style='day')

# %%
sns.relplot(data=df1,x = 'tip', y = 'total_bill', hue='size')

# %%
sns.relplot(data=df1,x = 'tip', y = 'total_bill', hue='smoker', style='time')

# %%
sns.relplot(data=df1,x = 'tip', y = 'total_bill', hue='sex', style='size')

# %%
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.
